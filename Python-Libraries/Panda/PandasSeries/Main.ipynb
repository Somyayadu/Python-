# %% [markdown]
# Python Day - 16
#
# Pandas Series

# %%
import pandas as pd
import numpy as np

# %%
# string

country =['india','pakisthan','usa','uk','nepal']

pd.Series(country)
# Out:
# 0        india
# 1    pakisthan
# 2          usa
# 3           uk
# 4        nepal
# dtype: object

# %%
# integers

runs = [13,23,45,56,34,457,84,9,0]

pd.Series(runs)
# Out:
# 0     13
# 1     23
# 2     45
# 3     56
# 4     34
# 5    457
# 6     84
# 7      9
# 8      0
# dtype: int64

# %%
# custom index

marks=[67,87,45,34]
subject=['math','hindi','english','sst']

pd.Series(marks,index=subject)
# Out:
# math       67
# hindi      87
# english    45
# sst        34
# dtype: int64

# %%
pd.Series(marks,index=subject,name='somya k marks')
# Out:
# math       67
# hindi      87
# english    45
# sst        34
# Name: somya k marks, dtype: int64

# %%
# series from dictionary

marks ={
    'math':76,
    'sst':54,
    'english':95,
    'eco':91
}

marks_series=pd.Series(marks,name='somya k marks')
marks_series
# Out:
# math       76
# sst        54
# english    95
# eco        91
# Name: somya k marks, dtype: int64

# %% [markdown]
# series attribute

# %%
# size
marks_series.size
# Out:
# 4

# %%
# dtype
marks_series.dtype
# Out:
# dtype('int64')

# %%
# name
marks_series.name
# Out:
# 'somya k marks'

# %%
# is_uniqe
marks_series.is_unique
# Out:
# True

# %%
# index
marks_series.index
# Out:
# Index(['math', 'sst', 'english', 'eco'], dtype='object')

# %%
# values
marks_series.values
# Out:
# array([76, 54, 95, 91], dtype=int64)

# %%
movies=pd.read_csv('Bollywood.csv',index_col='title')
movies
# Out:
#                                       imdbId  releaseYear  releaseDate  \
# title
# Albela                             tt0118578         2001  20 Apr 2001
# Lagaan: Once Upon a Time in India  tt0169102         2001  08 May 2002
# Meri Biwi Ka Jawab Nahin           tt0187279         2004  02 Jul 2004
# Hum Tumhare Hain Sanam             tt0222024         2002  24 May 2002
# One 2 Ka 4                         tt0227194         2001  30 Mar 2001
# ...                                      ...          ...          ...
# Shuruaat Ka Interval               tt4121522         2014  15 Aug 2014
# Trip to Bhangarh                   tt4187650         2014  28 Aug 2014
# Zed Plus                           tt4190220         2014  28 Nov 2014
# Gollu aur Pappu                    tt4219300         2014  21 Nov 2014
# Zid                                tt4228746         2014  28 Nov 2014
#
#                                                          genre  \
# title
# ...

# %%
vk=pd.read_csv('kohli_ipl.csv')
vk
# Out:
#     No.   Runs       Against  Position  Innings  \
# 0     1    107     Sri Lanka         4        2
# 1     2  102*     Bangladesh         3        2
# 2     3    118     Australia         3        2
# 3     4    105   New Zealand         3        1
# 4     5   100*    Bangladesh         4        1
# ..  ...    ...           ...       ...      ...
# 75   76    121   West Indies         4        1
# 76   77   122*      Pakistan         3        1
# 77   78   103*    Bangladesh         3        2
# 78   79   101*  South Africa         3        1
# 79   80    117   New Zealand         3        1
#
#                                             Venue   Ground       Date Result
# 0                           Eden Gardens, Kolkata     Home  24-Dec-09    Won
# 1            Sher-e-Bangla Cricket Stadium, Dhaka     Away  11-Jan-10    Won
# 2                APCA-VDCA Stadium, Visakhapatnam     Home  20-Oct-10    Won
# 3                         Nehru Stadium, Guwahati     Home  28-Nov-10    Won
# ...

# %%
subs=pd.read_csv('subs.csv')
subs
# Out:
#      rank                    Youtuber  subscribers      video views  \
# 0       1                    T-Series  222,000,000  198,459,090,822
# 1       2              YouTube Movies  154,000,000                0
# 2       3  Cocomelon - Nursery Rhymes  140,000,000  135,481,339,848
# 3       4                   SET India  139,000,000  125,764,252,686
# 4       5                       Music  116,000,000                0
# ..    ...                         ...          ...              ...
# 995   996                    JP Plays   10,900,000    4,609,300,218
# 996   997               TrapMusicHDTV   10,900,000    4,070,521,973
# 997   998                 Games EduUu   10,900,000    3,093,784,767
# 998   999                       Hueva   10,900,000    3,040,301,750
# 999  1000              Dobre Brothers   10,900,000    2,808,411,693
#
#     video count          category  started
# 0        17,317             Music     2006
# 1             0  Film & Animation     2015
# ...

# %% [markdown]
# Series Method

# %%
# head and tail

subs.head()
# Out:
#    rank                    Youtuber  subscribers      video views video count  \
# 0     1                    T-Series  222,000,000  198,459,090,822      17,317
# 1     2              YouTube Movies  154,000,000                0           0
# 2     3  Cocomelon - Nursery Rhymes  140,000,000  135,481,339,848         786
# 3     4                   SET India  139,000,000  125,764,252,686      91,271
# 4     5                       Music  116,000,000                0           0
#
#            category  started
# 0             Music     2006
# 1  Film & Animation     2015
# 2         Education     2006
# 3             Shows     2006
# 4               NaN     2013

# %%
vk.head(3)
# Out:
#    No.   Runs      Against  Position  Innings  \
# 0    1    107    Sri Lanka         4        2
# 1    2  102*    Bangladesh         3        2
# 2    3    118    Australia         3        2
#
#                                   Venue Ground       Date Result
# 0                 Eden Gardens, Kolkata   Home  24-Dec-09    Won
# 1  Sher-e-Bangla Cricket Stadium, Dhaka   Away  11-Jan-10    Won
# 2      APCA-VDCA Stadium, Visakhapatnam   Home  20-Oct-10    Won

# %%
vk.tail()
# Out:
#     No.  Runs       Against  Position  Innings  \
# 75   76   121   West Indies         4        1
# 76   77  122*      Pakistan         3        1
# 77   78  103*    Bangladesh         3        2
# 78   79  101*  South Africa         3        1
# 79   80   117   New Zealand         3        1
#
#                                             Venue   Ground       Date Result
# 75               Queen's Park Oval, Port of Spain     Away  20-Jul-23  Drawn
# 76                  R. Premadasa Stadium, Colombo  Neutral  11-Sep-23    Won
# 77  Maharashtra Cricket Association Stadium, Pune     Home  19-Oct-23    Won
# 78                          Eden Gardens, Kolkata      NaN     05-Nov    Won
# 79                       Wankhede Stadium, Mumbai     Home  15-Nov-23    Won

# %%
# sample
movies.sample()
# Out:
#                          imdbId  releaseYear  releaseDate  genre    writers  \
# title
# Love at Times Square  tt0345594         2003  14 Feb 2003  Drama  Dev Anand
#
#                                                                  actors  \
# title
# Love at Times Square  Dev Anand | Heenee Kaushik | Shoib Khan | Chai...
#
#                       directors  sequel  hitFlop
# title
# Love at Times Square  Dev Anand     0.0        1

# %%
# value_counts 
movies.value_counts()
# Out:
# imdbId     releaseYear  releaseDate  genre                      writers                                                                                                                                                                                              actors                                                                     directors                       sequel  hitFlop
# tt0118578  2001         20 Apr 2001  Romance                    Honey Irani (screenplay) | Honey Irani (story) | Javed Siddiqui (dialogue)                                                                                                                           Govinda | Aishwarya Rai Bachchan | Jackie Shroff | Namrata Shirodkar       Deepak Sareen                   0.0     2          1
# ...

# %%
vk.sort_values(by="Runs", ascending=False).head(1)
# Out:
#     No.   Runs        Against  Position  Innings  \
# 68   69  254*    South Africa         4        1
#
#                                             Venue Ground       Date Result
# 68  Maharashtra Cricket Association Stadium, Pune   Home  10-Oct-19    Won

# %%
vk.sort_values(by="Runs",  inplace=True)

# %%
vk
# Out:
#     No.   Runs        Against  Position  Innings  \
# 4     5   100*     Bangladesh         4        1
# 19   20   100*      Australia         3        2
# 78   79   101*   South Africa         3        1
# 17   18    102    West Indies         3        1
# 1     2  102*      Bangladesh         3        2
# ..  ...    ...            ...       ...      ...
# 37   38    211    New Zealand         4        1
# 50   51    213      Sri Lanka         4        2
# 40   41    235        England         4        2
# 51   52    243      Sri Lanka         4        1
# 68   69  254*    South Africa         4        1
#
#                                             Venue Ground       Date     Result
# 4            Sher-e-Bangla Cricket Stadium, Dhaka   Away  19-Feb-11        Won
# 19                 Sawai Mansingh Stadium, Jaipur   Home  16-Oct-13        Won
# 78                          Eden Gardens, Kolkata    NaN     05-Nov        Won
# ...

# %%
movies
# Out:
#                                       imdbId  releaseYear  releaseDate  \
# title
# Albela                             tt0118578         2001  20 Apr 2001
# Lagaan: Once Upon a Time in India  tt0169102         2001  08 May 2002
# Meri Biwi Ka Jawab Nahin           tt0187279         2004  02 Jul 2004
# Hum Tumhare Hain Sanam             tt0222024         2002  24 May 2002
# One 2 Ka 4                         tt0227194         2001  30 Mar 2001
# ...                                      ...          ...          ...
# Shuruaat Ka Interval               tt4121522         2014  15 Aug 2014
# Trip to Bhangarh                   tt4187650         2014  28 Aug 2014
# Zed Plus                           tt4190220         2014  28 Nov 2014
# Gollu aur Pappu                    tt4219300         2014  21 Nov 2014
# Zid                                tt4228746         2014  28 Nov 2014
#
#                                                          genre  \
# title
# ...

# %%
movies.sort_index(inplace=True)

# %%
movies
# Out:
#                                 imdbId  releaseYear  releaseDate  \
# title
# ...Yahaan                    tt0473567         2005  29 Jul 2005
# 13B: Fear Has a New Address  tt1385824         2009  06 Mar 2009
# 16 December                  tt0313844         2002  22 Mar 2002
# 1920                         tt1301698         2008  12 Sep 2008
# 1920: Evil Returns           tt2222550         2012  02 Nov 2012
# ...                                ...          ...          ...
# Zindagi Na Milegi Dobara     tt1562872         2011  15 Jul 2011
# Zindagi Tere Naam            tt2164702         2012  16 Mar 2012
# Zokkomon                     tt1605790         2011  22 Apr 2011
# Zor Lagaa Ke... Haiya!       tt1479857         2009  12 Jun 2009
# Zubeidaa                     tt0255713         2001  19 Jan 2001
#
#                                                      genre  \
# title
# ...Yahaan                                          Romance
# ...

# %% [markdown]
# Maths Method

# %%
# count 
vk.count()
# Out:
# No.         80
# Runs        80
# Against     80
# Position    80
# Innings     80
# Venue       80
# Ground      79
# Date        80
# Result      80
# dtype: int64

# %%
print(type(subs))
print(subs.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    rank                    Youtuber  subscribers      video views video count  \
# 0     1                    T-Series  222,000,000  198,459,090,822      17,317
# 1     2              YouTube Movies  154,000,000                0           0
# 2     3  Cocomelon - Nursery Rhymes  140,000,000  135,481,339,848         786
# 3     4                   SET India  139,000,000  125,764,252,686      91,271
# 4     5                       Music  116,000,000                0           0
#
#            category  started
# 0             Music     2006
# 1  Film & Animation     2015
# 2         Education     2006
# 3             Shows     2006
# 4               NaN     2013

# %%
print(movies.mode())
# Out:
#          imdbId  releaseYear  releaseDate  genre          writers  \
# 0     tt0118578       2010.0  02 Nov 2012  Drama     Dilip Shukla
# 1     tt0169102          NaN  09 May 2014    NaN  Nagesh Kukunoor
# 2     tt0187279          NaN          NaN    NaN              NaN
# 3     tt0222024          NaN          NaN    NaN              NaN
# 4     tt0227194          NaN          NaN    NaN              NaN
# ...         ...          ...          ...    ...              ...
# 1279  tt4121522          NaN          NaN    NaN              NaN
# 1280  tt4187650          NaN          NaN    NaN              NaN
# 1281  tt4190220          NaN          NaN    NaN              NaN
# 1282  tt4219300          NaN          NaN    NaN              NaN
# 1283  tt4228746          NaN          NaN    NaN              NaN
#
#                                                  actors     directors  sequel  \
# 0     'Chiyaan' Vikram | Neil Nitin Mukesh | Vinay V...  Priyadarshan     0.0
# ...

# %%
subs
# Out:
#      rank                    Youtuber  subscribers      video views  \
# 0       1                    T-Series  222,000,000  198,459,090,822
# 1       2              YouTube Movies  154,000,000                0
# 2       3  Cocomelon - Nursery Rhymes  140,000,000  135,481,339,848
# 3       4                   SET India  139,000,000  125,764,252,686
# 4       5                       Music  116,000,000                0
# ..    ...                         ...          ...              ...
# 995   996                    JP Plays   10,900,000    4,609,300,218
# 996   997               TrapMusicHDTV   10,900,000    4,070,521,973
# 997   998                 Games EduUu   10,900,000    3,093,784,767
# 998   999                       Hueva   10,900,000    3,040,301,750
# 999  1000              Dobre Brothers   10,900,000    2,808,411,693
#
#     video count          category  started
# 0        17,317             Music     2006
# 1             0  Film & Animation     2015
# ...

# %%
vk.describe()
# Out:
#            No.   Position   Innings
# count  80.0000  80.000000  80.00000
# mean   40.5000   3.500000   1.67500
# std    23.2379   0.656033   0.67082
# min     1.0000   2.000000   1.00000
# 25%    20.7500   3.000000   1.00000
# 50%    40.5000   3.000000   2.00000
# 75%    60.2500   4.000000   2.00000
# max    80.0000   6.000000   4.00000

# %% [markdown]
# Series Indexing

# %%
x = pd.Series([12,13,14,35,46,57,58,79,9])

# %%
x[0]
# Out:
# 12

# %%
# slicing
vk[-5:]
# Out:
#     No.   Runs        Against  Position  Innings  \
# 37   38    211    New Zealand         4        1
# 50   51    213      Sri Lanka         4        2
# 40   41    235        England         4        2
# 51   52    243      Sri Lanka         4        1
# 68   69  254*    South Africa         4        1
#
#                                             Venue Ground       Date Result
# 37                         Holkar Stadium, Indore   Home  08-Oct-16    Won
# 50   Vidarbha Cricket Association Stadium, Nagpur   Home  24-Nov-17    Won
# 40                       Wankhede Stadium, Mumbai   Home  08-Dec-16    Won
# 51                 Feroz Shah Kotla Ground, Delhi   Home  02-Dec-17  Drawn
# 68  Maharashtra Cricket Association Stadium, Pune   Home  10-Oct-19    Won

# %%
movies[-5:]
# Out:
#                              imdbId  releaseYear  releaseDate  \
# title
# Zindagi Na Milegi Dobara  tt1562872         2011  15 Jul 2011
# Zindagi Tere Naam         tt2164702         2012  16 Mar 2012
# Zokkomon                  tt1605790         2011  22 Apr 2011
# Zor Lagaa Ke... Haiya!    tt1479857         2009  12 Jun 2009
# Zubeidaa                  tt0255713         2001  19 Jan 2001
#
#                                                   genre  \
# title
# Zindagi Na Milegi Dobara     Adventure | Comedy | Drama
# Zindagi Tere Naam                               Romance
# Zokkomon                     Action | Adventure | Drama
# Zor Lagaa Ke... Haiya!          Comedy | Drama | Family
# Zubeidaa                  Adventure | Biography | Drama
#
#                                                                     writers  \
# title
# Zindagi Na Milegi Dobara  Farhan Akhtar (dialogue) | Zoya Akhtar (story)...
# ...

# %% [markdown]
# Edit series

# %%
marks_series[1]=100
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12904\676866948.py:1: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   marks_series[1]=100

# %%
marks_series
# Out:
# math        76
# sst        100
# english     95
# eco         91
# Name: somya k marks, dtype: int64

# %%
marks_series['science']=90

# %%
marks_series
# Out:
# math        76
# sst        100
# english     95
# eco         91
# science     90
# Name: somya k marks, dtype: int64

# %%
movies['1920: Evil Returns']='bhoot'

# %%
movies
# Out:
#                                 imdbId  releaseYear  releaseDate  \
# title
# ...Yahaan                    tt0473567         2005  29 Jul 2005
# 13B: Fear Has a New Address  tt1385824         2009  06 Mar 2009
# 16 December                  tt0313844         2002  22 Mar 2002
# 1920                         tt1301698         2008  12 Sep 2008
# 1920: Evil Returns           tt2222550         2012  02 Nov 2012
# ...                                ...          ...          ...
# Zindagi Na Milegi Dobara     tt1562872         2011  15 Jul 2011
# Zindagi Tere Naam            tt2164702         2012  16 Mar 2012
# Zokkomon                     tt1605790         2011  22 Apr 2011
# Zor Lagaa Ke... Haiya!       tt1479857         2009  12 Jun 2009
# Zubeidaa                     tt0255713         2001  19 Jan 2001
#
#                                                      genre  \
# title
# ...Yahaan                                          Romance
# ...

# %%
# functionalities

print(len(subs))
print(type(subs))
print(dir(subs))
print(sorted(subs))
print(min(subs))
print(max(subs))
# Out:
# 1000
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
# type conversion 

list(marks_series)
# Out:
# [76, 100, 95, 91, 90]

# %%
'13B: Fear Has a New Address' in movies
# Out:
# False

# %%
for i in movies: 
 print(i)
# Out:
# imdbId
# releaseYear
# releaseDate
# genre
# writers
# actors
# directors
# sequel
# hitFlop
# 1920: Evil Returns

# %%
100 - marks_series
# Out:
# math       24
# sst         0
# english     5
# eco         9
# science    10
# Name: somya k marks, dtype: int64

# %%
vk1=pd.read_csv('virat.csv')
vk1
# Out:
#     Season  Runs
# 0     2008   165
# 1     2009   246
# 2     2010   307
# 3     2011   557
# 4     2012   364
# 5     2013   634
# 6     2014   359
# 7     2015   505
# 8     2016   973
# 9     2017   308
# 10    2018   530
# 11    2019   464
# 12    2020   466
# 13    2021   405
# 14    2022   341
# 15    2023   639
# 16    2024   741
# 17    2025   657

# %%
vk1>=50
# Out:
#     Season  Runs
# 0     True  True
# 1     True  True
# 2     True  True
# 3     True  True
# 4     True  True
# 5     True  True
# 6     True  True
# 7     True  True
# 8     True  True
# 9     True  True
# 10    True  True
# 11    True  True
# 12    True  True
# 13    True  True
# 14    True  True
# 15    True  True
# 16    True  True
# 17    True  True

# %%
vk1[vk1 >= 50].size
# Out:
# 36

# %%
vk1 ==0
# Out:
#     Season   Runs
# 0    False  False
# 1    False  False
# 2    False  False
# 3    False  False
# 4    False  False
# 5    False  False
# 6    False  False
# 7    False  False
# 8    False  False
# 9    False  False
# 10   False  False
# 11   False  False
# 12   False  False
# 13   False  False
# 14   False  False
# 15   False  False
# 16   False  False
# 17   False  False

# %%
movies.value_counts()
# Out:
# imdbId     releaseYear  releaseDate  genre                      writers                                                                                                                                                                                              actors                                                                     directors                       sequel  hitFlop  1920: Evil Returns
# tt0118578  2001         20 Apr 2001  Romance                    Honey Irani (screenplay) | Honey Irani (story) | Javed Siddiqui (dialogue)                                                                                                                           Govinda | Aishwarya Rai Bachchan | Jackie Shroff | Namrata Shirodkar       Deepak Sareen                   0.0     2        bhoot                 1
# ...

# %%
num_movies=movies.value_counts()
num_movies[num_movies>20]
# Out:
# Series([], Name: count, dtype: int64)

# %%
subs.plot()
# Out:
# <Axes: >

# %%
movies.value_counts().head(20).plot(kind='bar')
# Out:
# <Axes: xlabel='imdbId,releaseYear,releaseDate,genre,writers,actors,directors,sequel,hitFlop,1920: Evil Returns'>

# %%
movies.value_counts().head(20).plot(kind='pie')
# Out:
# <Axes: ylabel='count'>
